# %%
from italian_csv_type_prediction.simple_types import ItalianFiscalCodeType, DateType, IntegerType
from italian_csv_type_prediction.column_types import AnyTypePredictor
import pandas as pd
from csv_trimming import trim_csv

# %%
from italian_csv_type_prediction.features.words import Words

# %%
feature = Words()

feature.score("ftgh///jk3343")
# Out:
# 6

# %%
from italian_csv_type_prediction import TypePredictor

# %%
predictor = ItalianFiscalCodeType()

# %%
predictor.validate("BDLMMD88S01Z336Z")
# Out:
# True

# %%
datePredictor = DateType()
datePredictor.validate("32/05/2018")
# Out:
# False

# %%
integerPredictor = IntegerType()
integerPredictor.validate("16/05/2018")
# Out:
# False

# %%
predictor = TypePredictor()

# %%
df = pd.read_csv("../../Desktop/esemioDemo/esempio1_marco.csv", sep=";", encoding = "ISO-8859-1", header=None, dtype="str")
df
# Out:
#                   0                                        1   \
# 0                 CF                         RAG.SOC./COGNOME
# 1   CRBMRL58E21F952R                                 CORBETTA
# 2   CSTMMM75R14D198U                                 CASTAGNA
# 3   DMRMRS69H49B300K                                 DI MARIA
# 4   FRSNMR54C70G273P                              FORESTIERI
# 5   FSCFBA79E12E131L                                   FUSCO
# 6   GRVLCU70H17F952K                               GARAVAGLIA
# 7   LRSRLB69P48D198G                                 LA ROSA
# 8   MGLMRK86H23D198K                                MAGELLANO
# 9   MHMHSM96H20Z336P                                 MOHAMED
# 10  MRLNNL61M58F952V                                   MERLO
# 11  NWZMMM84M06Z236D                                   NAWAZ
# 12  PRLSFN69T15H264R                                   PIROLA
# 13  PRZJNY78M08Z611R                                    PEREZ
# 14  PTTLSN83S69B300M                                   PITTA'
# 15  PVLMSG79R18Z129E                                   PAVEL
# 16  RCHLTM81L26Z330L                                  ORAICH
# 17  RSHFHN80E01Z236Y                                  IRSHAD
# 18  RVSMLL66H57D872G  RAVASI MIRELLA (Caffetteria Sister Sas)
# 19  RZZFRZ63M30E801B                           RIZZA FABRIZIO
# 20  SBTHMD59D09Z330L                                SABTAOUI
# 21  VCOVTR85P15Z100M                                     VOCI
# 22  VNIMHL72T03D198X                                   IOVINE
# 23  VRTGUO57S23M150G                                  VERATTI
# 24  ZHUSCH77T24Z210B                                      ZHU
# 25  ZNTLRT43P06B987J                                    ZENTI
#
#                          2                3                  4      5   \
# 0                      NOME  DATA DI NASCITA  COMUNE DI NASCITA  SESSO
# 1                     MAURO              NaN                NaN    NaN
# 2                     MIMMO              NaN                NaN
# 3                MARIA ROSA              NaN                NaN    NaN
# 4                ANNA MARIA              NaN                NaN    NaN
# 5                     FABIO              NaN                NaN    NaN
# 6                      LUCA              NaN                NaN    NaN
# 7             ROSALBA MARIA              NaN                NaN    NaN
# 8                     MIRKO              NaN                NaN    NaN
# 9   HOSSAM ATEF SALAH ELDIN              NaN                NaN    NaN
# 10                ANTONELLA              NaN                NaN    NaN
# 11                 MUHAMMAD              NaN                NaN    NaN
# 12                  STEFANO              NaN                NaN
# 13                    JONNY              NaN                NaN    NaN
# 14               ALESSANDRA              NaN                NaN    NaN
# 15             MARIUS GIGEL              NaN                NaN    NaN
# 16                 EL FATMI              NaN                NaN    NaN
# 17                   FARHAN              NaN                NaN    NaN
# 18                      NaN              NaN                NaN    NaN
# 19                 FABRIZIO              NaN                NaN
# 20                    AHMED              NaN                NaN    NaN
# 21                    VITOR              NaN                NaN    NaN
# 22                  MICHELE              NaN                NaN    NaN
# 23                      UGO              NaN                NaN    NaN
# 24                 SHOUCHAO              NaN                NaN    NaN
# 25                  ALBERTO              NaN                NaN    NaN
#
#                                                    6      7      8     9   \
# 0                               Indirizzo (Residenza)     N.  SUFF.  INT.
# 1                                     VIA MONTE NERO      17    NaN   NaN
# 2                                       VIA B. CROCE      3A    NaN   NaN
# 3                                    VIA COL DI LANA       6    NaN   NaN
# 4                                 VIA 25 APRILE 1945    39/A    NaN   NaN
# 5                            STRADA PRIVATA G. VERDI       6    NaN   NaN
# 6                                 VIA 25 APRILE 1945      34    NaN   NaN
# 7                               VICOLO LEONE TOLSTOI       2    NaN   NaN
# 8                                     VIA SAN PIETRO      40      1     6
# 9                              VIA MONTE SAN GENESIO      13    NaN   NaN
# 10                             VIA CAVALLOTTI FELICE      11    NaN   NaN
# 11                                VIA 25 APRILE 1945      11    NaN   NaN
# 12                                   VIA S. VINCENZO       9    NaN   NaN
# 13                                         VIA FIORI       1    NaN   NaN
# 14                                       VIA LIBERT·      49    NaN   NaN
# 15                                   VIA S. VINCENZO       6    NaN   NaN
# 16              17 COURS SAINT ANDRÔ , LIONE ,FRANCIA    NaN    NaN   NaN
# 17                                        VIA ACERBI      10    NaN   NaN
# 18                                          VIA ROMA      19    NaN   NaN
# 19                                  VIA E. VILLORESI      24    NaN   NaN
# 20         7 PLACE LIONNEL TERRAY , GRENOBLE, FRANCIA    NaN    NaN   NaN
# 21                                      VIA MOLINARA      36    NaN   NaN
# 22                               REGIONE CONTRALONGA       3    NaN   NaN
# 23                                VIA 25 APRILE 1945      15    NaN   NaN
# 24                                  VIA MONTE GRAPPA       6    NaN   NaN
# 25  17 RUE CHEIKH ZARROUK APP. 5 MAARIF , CASABLAN...    NaN    NaN   NaN
#
#     ...                 31                32          33  \
# 0   ...  OMESSO VERSAMENTO  INTERESSI LEGALI  DATA EMIS/
# 1   ...                NaN               NaN  20/11/2018
# 2   ...                NaN               NaN  13/06/2018
# 3   ...                NaN               NaN  11/06/2018
# 4   ...                NaN               NaN  06/11/2017
# 5   ...                NaN               NaN  16/11/2018
# 6   ...                NaN               NaN  05/07/2018
# 7   ...                NaN               NaN  13/06/2018
# 8   ...                NaN               NaN  11/06/2018
# 9   ...                NaN               NaN  13/06/2018
# 10  ...                NaN               NaN  01/06/2018
# 11  ...                NaN               NaN  18/06/2018
# 12  ...                NaN               NaN  13/06/2018
# 13  ...                NaN               NaN  09/10/2018
# 14  ...                NaN               NaN  11/06/2018
# 15  ...                NaN               NaN  18/06/2018
# 16  ...                NaN               NaN  15/11/2018
# 17  ...                NaN               NaN  13/06/2018
# 18  ...                NaN               NaN  09/10/2018
# 19  ...                NaN               NaN  18/06/2018
# 20  ...                NaN               NaN  25/10/2018
# 21  ...                NaN               NaN  15/10/2018
# 22  ...                NaN               NaN  15/10/2018
# 23  ...                NaN               NaN  02/11/2018
# 24  ...                NaN               NaN  18/06/2018
# 25  ...                NaN               NaN  15/11/2018
#
#                                   34                       35             36  \
# 0   DATA NOTIFICA (NO DATA SCADENZA)  INFORMAZIONE AGGIUNTIVA  INDIRIZZO PEC
# 1                         23/11/2018                      NaN            NaN
# 2                         16/10/2018                      NaN            NaN
# 3                         10/08/2018                      NaN            NaN
# 4                         09/11/2017                      NaN            NaN
# 5                         21/11/2018                      NaN            NaN
# 6                         05/07/2018                      NaN            NaN
# 7                         16/10/2018                      NaN            NaN
# 8                         15/10/2018                      NaN            NaN
# 9                         16/10/2018                      NaN            NaN
# 10                        17/11/2018                      NaN            NaN
# 11                        17/08/2018                      NaN            NaN
# 12                        09/08/2018                      NaN            NaN
# 13                        17/10/2018                      NaN            NaN
# 14                        20/08/2018                      NaN            NaN
# 15                        07/08/2018                      NaN            NaN
# 16                        22/11/2018                      NaN            NaN
# 17                        17/08/2018                      NaN            NaN
# 18                        10/10/2018                      NaN            NaN
# 19                        27/11/2018                      NaN            NaN
# 20                        02/11/2018                      NaN            NaN
# 21                        16/10/2018                      NaN            NaN
# 22                        19/10/2018                      NaN            NaN
# 23                        13/11/2018                      NaN            NaN
# 24                        09/08/2018                      NaN            NaN
# 25                        04/12/2018                      NaN            NaN
#
#                         37                               38  \
# 0   MAGGIORAZIONE DI LEGGE  MAGGIORAZIONE STATALE \n(TARES)
# 1                      NaN                              NaN
# 2                      NaN                              NaN
# 3                      NaN                              NaN
# 4                      NaN                              NaN
# 5                      NaN                              NaN
# 6                      NaN                              NaN
# 7                      NaN                              NaN
# 8                      NaN                              NaN
# 9                      NaN                              NaN
# 10                     NaN                              NaN
# 11                     NaN                              NaN
# 12                     NaN                              NaN
# 13                     NaN                              NaN
# 14                     NaN                              NaN
# 15                     NaN                              NaN
# 16                     NaN                              NaN
# 17                     NaN                              NaN
# 18                     NaN                              NaN
# 19                     NaN                              NaN
# 20                     NaN                              NaN
# 21                     NaN                              NaN
# 22                     NaN                              NaN
# 23                     NaN                              NaN
# 24                     NaN                              NaN
# 25                     NaN                              NaN
#
#                       39              40
# 0   spese procedura ente  data scadenza
# 1                    NaN             NaN
# 2                    NaN             NaN
# 3                    NaN             NaN
# 4                    NaN             NaN
# 5                    NaN             NaN
# 6                    NaN             NaN
# 7                    NaN             NaN
# 8                    NaN             NaN
# 9                    NaN             NaN
# 10                   NaN             NaN
# 11                   NaN             NaN
# 12                   NaN             NaN
# 13                   NaN             NaN
# 14                   NaN             NaN
# 15                   NaN             NaN
# 16                   NaN             NaN
# 17                   NaN             NaN
# 18                   NaN             NaN
# 19                   NaN             NaN
# 20                   NaN             NaN
# 21                   NaN             NaN
# 22                   NaN             NaN
# 23                   NaN             NaN
# 24                   NaN             NaN
# 25                   NaN             NaN
#
# [26 rows x 41 columns]

# %%
df = trim_csv(df)
df
# Out:
#                   CF                         RAG.SOC./COGNOME  \
# 0   CRBMRL58E21F952R                                 CORBETTA
# 1   CSTMMM75R14D198U                                 CASTAGNA
# 2   DMRMRS69H49B300K                                 DI MARIA
# 3   FRSNMR54C70G273P                               FORESTIERI
# 4   FSCFBA79E12E131L                                    FUSCO
# 5   GRVLCU70H17F952K                               GARAVAGLIA
# 6   LRSRLB69P48D198G                                  LA ROSA
# 7   MGLMRK86H23D198K                                MAGELLANO
# 8   MHMHSM96H20Z336P                                  MOHAMED
# 9   MRLNNL61M58F952V                                    MERLO
# 10  NWZMMM84M06Z236D                                    NAWAZ
# 11  PRLSFN69T15H264R                                   PIROLA
# 12  PRZJNY78M08Z611R                                    PEREZ
# 13  PTTLSN83S69B300M                                   PITTA'
# 14  PVLMSG79R18Z129E                                    PAVEL
# 15  RCHLTM81L26Z330L                                   ORAICH
# 16  RSHFHN80E01Z236Y                                   IRSHAD
# 17  RVSMLL66H57D872G  RAVASI MIRELLA (Caffetteria Sister Sas)
# 18  RZZFRZ63M30E801B                           RIZZA FABRIZIO
# 19  SBTHMD59D09Z330L                                 SABTAOUI
# 20  VCOVTR85P15Z100M                                     VOCI
# 21  VNIMHL72T03D198X                                   IOVINE
# 22  VRTGUO57S23M150G                                  VERATTI
# 23  ZHUSCH77T24Z210B                                      ZHU
# 24  ZNTLRT43P06B987J                                    ZENTI
#
#                        NOME  \
# 0                     MAURO
# 1                     MIMMO
# 2                MARIA ROSA
# 3                ANNA MARIA
# 4                     FABIO
# 5                      LUCA
# 6             ROSALBA MARIA
# 7                     MIRKO
# 8   HOSSAM ATEF SALAH ELDIN
# 9                 ANTONELLA
# 10                 MUHAMMAD
# 11                  STEFANO
# 12                    JONNY
# 13               ALESSANDRA
# 14             MARIUS GIGEL
# 15                 EL FATMI
# 16                   FARHAN
# 17                      NaN
# 18                 FABRIZIO
# 19                    AHMED
# 20                    VITOR
# 21                  MICHELE
# 22                      UGO
# 23                 SHOUCHAO
# 24                  ALBERTO
#
#                                 Indirizzo (Residenza)    N. SUFF. INT.    CAP  \
# 0                                      VIA MONTE NERO    17   NaN  NaN  20029
# 1                                        VIA B. CROCE    3A   NaN  NaN  20022
# 2                                     VIA COL DI LANA     6   NaN  NaN  20029
# 3                                  VIA 25 APRILE 1945  39/A   NaN  NaN  20029
# 4                             STRADA PRIVATA G. VERDI     6   NaN  NaN  20020
# 5                                  VIA 25 APRILE 1945    34   NaN  NaN  20029
# 6                                VICOLO LEONE TOLSTOI     2   NaN  NaN  28066
# 7                                      VIA SAN PIETRO    40     1    6  20010
# 8                               VIA MONTE SAN GENESIO    13   NaN  NaN  20158
# 9                               VIA CAVALLOTTI FELICE    11   NaN  NaN  20020
# 10                                 VIA 25 APRILE 1945    11   NaN  NaN  20029
# 11                                    VIA S. VINCENZO     9   NaN  NaN  20029
# 12                                          VIA FIORI     1   NaN  NaN  20020
# 13                                        VIA LIBERT·    49   NaN  NaN  20029
# 14                                    VIA S. VINCENZO     6   NaN  NaN  20029
# 15              17 COURS SAINT ANDRÔ , LIONE ,FRANCIA   NaN   NaN  NaN    NaN
# 16                                         VIA ACERBI    10   NaN  NaN  20022
# 17                                           VIA ROMA    19   NaN  NaN  20029
# 18                                   VIA E. VILLORESI    24   NaN  NaN  20029
# 19         7 PLACE LIONNEL TERRAY , GRENOBLE, FRANCIA   NaN   NaN  NaN    NaN
# 20                                       VIA MOLINARA    36   NaN  NaN  20029
# 21                                REGIONE CONTRALONGA     3   NaN  NaN   7020
# 22                                 VIA 25 APRILE 1945    15   NaN  NaN  20029
# 23                                   VIA MONTE GRAPPA     6   NaN  NaN  20029
# 24  17 RUE CHEIKH ZARROUK APP. 5 MAARIF , CASABLAN...   NaN   NaN  NaN    NaN
#
#         Comune (Residenza) PROV (Residenza)  ... DETTAGLIO_PRODOTTO  \
# 0                  TURBIGO               MI  ...               TARI
# 1            CASTANO PRIMO               MI  ...               TARI
# 2                  TURBIGO               MI  ...               TARI
# 3                  TURBIGO               MI  ...               TARI
# 4   ROBECCHETTO CON INDUNO               MI  ...               TARI
# 5                  TURBIGO               MI  ...               TARI
# 6                 GALLIATE               NO  ...               TARI
# 7                  BUSCATE               MI  ...               TARI
# 8                   MILANO               MI  ...               TARI
# 9                  BUSCATE               MI  ...               TARI
# 10                 TURBIGO               MI  ...               TARI
# 11                 TURBIGO               MI  ...               TARI
# 12  ROBECCHETTO CON INDUNO               MI  ...               TARI
# 13                 TURBIGO               MI  ...               TARI
# 14                 TURBIGO               MI  ...               TARI
# 15                     NaN              NaN  ...               TARI
# 16           CASTANO PRIMO               MI  ...               TARI
# 17                 TURBIGO               MI  ...               TARI
# 18                 TURBIGO               MI  ...               TARI
# 19                     NaN              NaN  ...               TARI
# 20                 TURBIGO               MI  ...               TARI
# 21                   MONTI               SS  ...               TARI
# 22                 TURBIGO               MI  ...               TARI
# 23                 TURBIGO               MI  ...               TARI
# 24                     NaN              NaN  ...               TARI
#
#    TIPO DOCUMENTO DESCRIZIONE NUM DOC          ANNO DOC CONTR.PROV  \
# 0          AVVISO      AVVISO   15748  2015, 2016, 2017       9,76
# 1          AVVISO      AVVISO    8738  2015, 2016, 2017         18
# 2          AVVISO      AVVISO    8572  2015, 2016, 2017          4
# 3          AVVISO      AVVISO   13973  2015, 2016, 2017         35
# 4          AVVISO      AVVISO     319  2015, 2016, 2017          4
# 5          AVVISO      AVVISO   10084  2015, 2016, 2017      15,52
# 6          AVVISO      AVVISO    8730  2015, 2016, 2017          8
# 7          AVVISO      AVVISO    8606  2015, 2016, 2017         11
# 8          AVVISO      AVVISO    8728  2015, 2016, 2017         11
# 9          AVVISO      AVVISO    8578  2015, 2016, 2017         21
# 10         AVVISO      AVVISO    8923  2015, 2016, 2017          7
# 11         AVVISO      AVVISO    8763  2015, 2016, 2017         36
# 12         AVVISO      AVVISO   13837  2015, 2016, 2017         12
# 13         AVVISO      AVVISO    8575  2015, 2016, 2017         41
# 14         AVVISO      AVVISO    8926  2015, 2016, 2017         27
# 15         AVVISO      AVVISO     578  2015, 2016, 2017         18
# 16         AVVISO      AVVISO    8762  2015, 2016, 2017         31
# 17         AVVISO      AVVISO    1323  2015, 2016, 2017         40
# 18         AVVISO      AVVISO    8930  2015, 2016, 2017         16
# 19         AVVISO      AVVISO   14226  2015, 2016, 2017         52
# 20         AVVISO      AVVISO    8931  2015, 2016, 2017         16
# 21         AVVISO      AVVISO     382  2015, 2016, 2017          4
# 22         AVVISO      AVVISO   14961        2015, 2016         41
# 23         AVVISO      AVVISO    8924  2015, 2016, 2017         48
# 24         AVVISO      AVVISO     862  2015, 2016, 2017         32
#
#    SPESE POSTALI ATTO IMPOSTA  DATA EMIS/ DATA NOTIFICA (NO DATA SCADENZA)
# 0                5,88     195  20/11/2018                       23/11/2018
# 1                5,88     355  13/06/2018                       16/10/2018
# 2                5,88      78  11/06/2018                       10/08/2018
# 3                5,88     690  06/11/2017                       09/11/2017
# 4                5,88      87  16/11/2018                       21/11/2018
# 5                 NaN     310  05/07/2018                       05/07/2018
# 6                5,88     188  13/06/2018                       16/10/2018
# 7                5,88     217  11/06/2018                       15/10/2018
# 8                5,88     222  13/06/2018                       16/10/2018
# 9                5,88     421  01/06/2018                       17/11/2018
# 10               5,88     140  18/06/2018                       17/08/2018
# 11               5,88     711  13/06/2018                       09/08/2018
# 12               5,88     232  09/10/2018                       17/10/2018
# 13               5,88     817  11/06/2018                       20/08/2018
# 14               5,88     545  18/06/2018                       07/08/2018
# 15               5,88     364  15/11/2018                       22/11/2018
# 16               5,88     612  13/06/2018                       17/08/2018
# 17                  6     803  09/10/2018                       10/10/2018
# 18                  6     323  18/06/2018                       27/11/2018
# 19               5,88    1040  25/10/2018                       02/11/2018
# 20               5,88     329  15/10/2018                       16/10/2018
# 21               5,88      88  15/10/2018                       19/10/2018
# 22               5,88     815  02/11/2018                       13/11/2018
# 23               5,88     957  18/06/2018                       09/08/2018
# 24               5,88     648  15/11/2018                       04/12/2018
#
# [25 rows x 21 columns]

# %%
any_predictor = AnyTypePredictor()
    
any_predictor.predict(df["DETTAGLIO_PRODOTTO"], [None]*df.shape[0], [None]*df.shape[0])
# Out:
# {'Address': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'ItalianZIPCode': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'ItalianFiscalCode': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'CountryCode': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Country': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Date': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'EMail': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Float': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Integer': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'ItalianVAT': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Document': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Municipality': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Name': [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  'NaN': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'PhoneNumber': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'ProvinceCode': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Region': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'String': [True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True],
#  'Surname': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Year': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'BiologicalSex': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Boolean': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'Plate': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'CadastreCode': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False]}

# %%
df.values[:, 0]
# Out:
# array(['1', '2', '3', '4', '5', '6', '7', '8'], dtype=object)

# %%
df
# Out:
#   column 0        CF-PERSONA            Ragione Sociale     Indirizzo casa  \
# 0        1  VRSMNT72M57D976N  BERSACI, MARIA ANTONIETTA           VIA MEDA
# 1        2  BTACHR82P57F205V              ABATE, CHIARA       VIA NEGRELLI
# 2        3  BBNFNC79P08F205P         ABBONDI, FRANCESCO   VICOLO TOSCANINI
# 3        4         463700583                ROTOCOLORPA        VIA GORIZIA
# 4        5         828430157             QUADRATEC.R.L.        VIA GORIZIA
# 5        6        2774940965             NEWAPIRUS.A.S.         VIA TURATI
# 6        7  BDLMMD88S01Z336Z              Neri,  RAHMAM  VIA DELLA FILANDA
# 7        8  BDLMMD71M22Z336D         ABDELAZIZ, MOHAMED    VIA SAN MASSIMO
#
#    N.    CAP    Comune PROV NUM. DOC. ANNO DOC IMPORTO   DATA EMIS  \
# 0   8  20018  SEDRIANO  MII     16035     2018    1710  16/05/2018
# 1   3  20018  SEDRIANO   MI         1     2018     172  16/05/2018
# 2  26  20018  SERRIANO   GE     20100     2018      21  16/05/2018
# 3  18  20018  SEDRIANO   MI         9     2018     347    16052018
# 4  18  20018  SERRIANO   MI        11     1018     351  16/05/2018
# 5  40  20018  SEDRIANO   MI        12     2018     277  32/05/2018
# 6  11  20018  SEDRIANO   MI        13     2018      57  16/13/2018
# 7  62  20018  SEDRIANO   MI        14     2018     294  16/05/2018
#
#                                           Nominativo
# 0                                                NaN
# 1                                                NaN
# 2           erede: Maria Rossi  CF: RSSMRA80A01H501U
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Legale Rappresentante: Manuela Gialli CF:  GLL...

# %%
predictor.predict_dataframe(df)
# Out:
#                    CF RAG.SOC./COGNOME  NOME Indirizzo (Residenza)       N.  \
# 0   ItalianFiscalCode          Surname  Name               Address  Integer
# 1   ItalianFiscalCode          Surname  Name               Address    Error
# 2   ItalianFiscalCode          Surname  Name               Address  Integer
# 3   ItalianFiscalCode          Surname  Name               Address    Error
# 4   ItalianFiscalCode          Surname  Name               Address  Integer
# 5   ItalianFiscalCode          Surname  Name               Address  Integer
# 6   ItalianFiscalCode          Surname  Name               Address  Integer
# 7   ItalianFiscalCode          Surname  Name               Address  Integer
# 8   ItalianFiscalCode          Surname  Name               Address  Integer
# 9   ItalianFiscalCode          Surname  Name               Address  Integer
# 10  ItalianFiscalCode          Surname  Name               Address  Integer
# 11  ItalianFiscalCode          Surname  Name               Address  Integer
# 12  ItalianFiscalCode          Surname  Name               Address  Integer
# 13  ItalianFiscalCode          Surname  Name               Address  Integer
# 14  ItalianFiscalCode          Surname  Name               Address  Integer
# 15  ItalianFiscalCode          Surname  Name                 Error      NaN
# 16  ItalianFiscalCode          Surname  Name               Address  Integer
# 17  ItalianFiscalCode          Surname   NaN               Address  Integer
# 18  ItalianFiscalCode          Surname  Name               Address  Integer
# 19  ItalianFiscalCode          Surname  Name                 Error      NaN
# 20  ItalianFiscalCode          Surname  Name               Address  Integer
# 21  ItalianFiscalCode          Surname  Name                 Error  Integer
# 22  ItalianFiscalCode          Surname  Name               Address  Integer
# 23  ItalianFiscalCode          Surname  Name               Address  Integer
# 24  ItalianFiscalCode          Surname  Name                 Error      NaN
#
#     SUFF.   INT.             CAP Comune (Residenza) PROV (Residenza)  ...  \
# 0     NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 1     NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 2     NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 3     NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 4     NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 5     NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 6     NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 7   Float  Float  ItalianZIPCode       Municipality     ProvinceCode  ...
# 8     NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 9     NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 10    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 11    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 12    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 13    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 14    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 15    NaN    NaN             NaN                NaN              NaN  ...
# 16    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 17    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 18    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 19    NaN    NaN             NaN                NaN              NaN  ...
# 20    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 21    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 22    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 23    NaN    NaN  ItalianZIPCode       Municipality     ProvinceCode  ...
# 24    NaN    NaN             NaN                NaN              NaN  ...
#
#    DETTAGLIO_PRODOTTO TIPO DOCUMENTO DESCRIZIONE  NUM DOC ANNO DOC CONTR.PROV  \
# 0               Error       Document    Document  Integer    Error    Integer
# 1               Error       Document    Document  Integer    Error    Integer
# 2               Error       Document    Document  Integer    Error    Integer
# 3               Error       Document    Document  Integer    Error    Integer
# 4               Error       Document    Document  Integer    Error    Integer
# 5               Error       Document    Document  Integer    Error    Integer
# 6               Error       Document    Document  Integer    Error    Integer
# 7               Error       Document    Document  Integer    Error    Integer
# 8               Error       Document    Document  Integer    Error    Integer
# 9               Error       Document    Document  Integer    Error    Integer
# 10              Error       Document    Document  Integer    Error    Integer
# 11              Error       Document    Document  Integer    Error    Integer
# 12              Error       Document    Document  Integer    Error    Integer
# 13              Error       Document    Document  Integer    Error    Integer
# 14              Error       Document    Document  Integer    Error    Integer
# 15              Error       Document    Document  Integer    Error    Integer
# 16              Error       Document    Document  Integer    Error    Integer
# 17              Error       Document    Document  Integer    Error    Integer
# 18              Error       Document    Document  Integer    Error    Integer
# 19              Error       Document    Document  Integer    Error    Integer
# 20              Error       Document    Document  Integer    Error    Integer
# 21              Error       Document    Document  Integer    Error    Integer
# 22              Error       Document    Document  Integer    Error    Integer
# 23              Error       Document    Document  Integer    Error    Integer
# 24              Error       Document    Document  Integer    Error    Integer
#
#    SPESE POSTALI ATTO  IMPOSTA DATA EMIS/ DATA NOTIFICA (NO DATA SCADENZA)
# 0               Float  Integer       Date                             Date
# 1               Float  Integer       Date                             Date
# 2               Float  Integer       Date                             Date
# 3               Float  Integer       Date                             Date
# 4               Float  Integer       Date                             Date
# 5                 NaN  Integer       Date                             Date
# 6               Float  Integer       Date                             Date
# 7               Float  Integer       Date                             Date
# 8               Float  Integer       Date                             Date
# 9               Float  Integer       Date                             Date
# 10              Float  Integer       Date                             Date
# 11              Float  Integer       Date                             Date
# 12              Float  Integer       Date                             Date
# 13              Float  Integer       Date                             Date
# 14              Float  Integer       Date                             Date
# 15              Float  Integer       Date                             Date
# 16              Float  Integer       Date                             Date
# 17              Float  Integer       Date                             Date
# 18              Float  Integer       Date                             Date
# 19              Float  Integer       Date                             Date
# 20              Float  Integer       Date                             Date
# 21              Float  Integer       Date                             Date
# 22              Float  Integer       Date                             Date
# 23              Float  Integer       Date                             Date
# 24              Float  Integer       Date                             Date
#
# [25 rows x 21 columns]
