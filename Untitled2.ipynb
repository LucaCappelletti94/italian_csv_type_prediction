# %%
from italian_csv_type_prediction.simple_types import ItalianFiscalCodeType, CurrencyType, DateType, IntegerType
from italian_csv_type_prediction.column_types import AnyTypePredictor
import pandas as pd
from csv_trimming import trim_csv

# %%
from italian_csv_type_prediction.features.words import Words

# %%
feature = Words()

feature.score("ftgh///jk3343")
# Out:
# 6

# %%
from italian_csv_type_prediction import TypePredictor

# %%
predictor = ItalianFiscalCodeType()

# %%
predictor.validate("BDLMMD88S01Z336Z")
# Out:
# True

# %%
predictor = CurrencyType()

# %%
predictor.validate("erede: Maria Rossi CF: RSSMRA80A01H501U")
# Out:
# False

# %%
datePredictor = DateType()
datePredictor.validate("32/05/2018")
# Out:
# False

# %%
integerPredictor = IntegerType()
integerPredictor.validate("16/05/2018")
# Out:
# False

# %%
predictor = TypePredictor()

# %%
df = pd.read_csv("../../Desktop/esemioDemo/esemioDeno2.csv", sep=";", header=None, dtype="str")
df
# Out:
#      0                                                  1   \
# 0   NaN             Dettaglio delle bollette da riscuotere
# 1   NaN                                                NaN
# 2   NaN                                                NaN
# 3   NaN                                         CF-PERSONA
# 4     1                                   VRSMNT72M57D976N
# 5     2                                   BTACHR82P57F205V
# 6     3                                   BBNFNC79P08F205P
# 7     4                                          463700583
# 8     5                                          828430157
# 9     6                                         2774940965
# 10    7                                   BDLMMD88S01Z336Z
# 11    8                                   BDLMMD71M22Z336D
# 12  NaN                                                NaN
# 13  NaN                                                NaN
# 14  NaN  I dati prodotti in questo documento sono confo...
# 15  NaN                                                NaN
# 16  NaN                                                NaN
#
#                            2                  3    4      5         6     7   \
# 0                         NaN                NaN  NaN    NaN       NaN   NaN
# 1                         NaN                NaN  NaN    NaN       NaN   NaN
# 2                         NaN                NaN  NaN    NaN       NaN   NaN
# 3             Ragione Sociale     Indirizzo casa   N.    CAP    Comune  PROV
# 4   BERSACI, MARIA ANTONIETTA           VIA MEDA    8  20018  SEDRIANO   MII
# 5               ABATE, CHIARA       VIA NEGRELLI    3  20018  SEDRIANO    MI
# 6          ABBONDI, FRANCESCO   VICOLO TOSCANINI   26  20018  SERRIANO    GE
# 7                 ROTOCOLORPA        VIA GORIZIA   18  20018  SEDRIANO    MI
# 8              QUADRATEC.R.L.        VIA GORIZIA   18  20018  SERRIANO    MI
# 9              NEWAPIRUS.A.S.         VIA TURATI   40  20018  SEDRIANO    MI
# 10              Neri,  RAHMAM  VIA DELLA FILANDA   11  20018  SEDRIANO    MI
# 11         ABDELAZIZ, MOHAMED    VIA SAN MASSIMO   62  20018  SEDRIANO    MI
# 12                        NaN                NaN  NaN    NaN       NaN   NaN
# 13                        NaN                NaN  NaN    NaN       NaN   NaN
# 14                        NaN                NaN  NaN    NaN       NaN   NaN
# 15                        NaN                NaN  NaN    NaN       NaN   NaN
# 16      Totale delle bollette               3229  NaN    NaN       NaN   NaN
#
#            8         9        10          11  \
# 0         NaN       NaN      NaN         NaN
# 1         NaN       NaN      NaN         NaN
# 2         NaN       NaN      NaN         NaN
# 3   NUM. DOC.  ANNO DOC  IMPORTO   DATA EMIS
# 4       16035      2018     1710  16/05/2018
# 5           1      2018      172  16/05/2018
# 6       20100      2018       21  16/05/2018
# 7           9      2018      347    16052018
# 8          11      1018      351  16/05/2018
# 9          12      2018      277  32/05/2018
# 10         13      2018       57  16/13/2018
# 11         14      2018      294  16/05/2018
# 12        NaN       NaN      NaN         NaN
# 13        NaN       NaN      NaN         NaN
# 14        NaN       NaN      NaN         NaN
# 15        NaN       NaN      NaN         NaN
# 16        NaN       NaN      NaN         NaN
#
#                                                    12
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                          Nominativo
# 4                                                 NaN
# 5                                                 NaN
# 6            erede: Maria Rossi  CF: RSSMRA80A01H501U
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Legale Rappresentante: Manuela Gialli CF:  GLL...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN

# %%
df = trim_csv(df)
df
# Out:
#   column 0        CF-PERSONA            Ragione Sociale     Indirizzo casa  \
# 0        1  VRSMNT72M57D976N  BERSACI, MARIA ANTONIETTA           VIA MEDA
# 1        2  BTACHR82P57F205V              ABATE, CHIARA       VIA NEGRELLI
# 2        3  BBNFNC79P08F205P         ABBONDI, FRANCESCO   VICOLO TOSCANINI
# 3        4         463700583                ROTOCOLORPA        VIA GORIZIA
# 4        5         828430157             QUADRATEC.R.L.        VIA GORIZIA
# 5        6        2774940965             NEWAPIRUS.A.S.         VIA TURATI
# 6        7  BDLMMD88S01Z336Z              Neri,  RAHMAM  VIA DELLA FILANDA
# 7        8  BDLMMD71M22Z336D         ABDELAZIZ, MOHAMED    VIA SAN MASSIMO
#
#    N.    CAP    Comune PROV NUM. DOC. ANNO DOC IMPORTO   DATA EMIS  \
# 0   8  20018  SEDRIANO  MII     16035     2018    1710  16/05/2018
# 1   3  20018  SEDRIANO   MI         1     2018     172  16/05/2018
# 2  26  20018  SERRIANO   GE     20100     2018      21  16/05/2018
# 3  18  20018  SEDRIANO   MI         9     2018     347    16052018
# 4  18  20018  SERRIANO   MI        11     1018     351  16/05/2018
# 5  40  20018  SEDRIANO   MI        12     2018     277  32/05/2018
# 6  11  20018  SEDRIANO   MI        13     2018      57  16/13/2018
# 7  62  20018  SEDRIANO   MI        14     2018     294  16/05/2018
#
#                                           Nominativo
# 0                                                NaN
# 1                                                NaN
# 2           erede: Maria Rossi  CF: RSSMRA80A01H501U
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Legale Rappresentante: Manuela Gialli CF:  GLL...

# %%
any_predictor = AnyTypePredictor()
    
any_predictor.predict(df.values[:, 10], [None]*df.shape[0], [None]*df.shape[0])
# Out:
# {'Address': [False, False, False, False, False, False, False, False],
#  'ItalianZIPCode': [False, False, False, False, False, False, False, False],
#  'ItalianFiscalCode': [False, False, False, False, False, False, False, False],
#  'CountryCode': [False, False, False, False, False, False, False, False],
#  'Country': [False, False, False, False, False, False, False, False],
#  'Currency': [True, True, True, True, True, True, True, True],
#  'Date': [False, False, False, False, False, False, False, False],
#  'EMail': [False, False, False, False, False, False, False, False],
#  'Float': [True, True, True, True, True, True, True, True],
#  'Integer': [True, True, True, True, True, True, True, True],
#  'ItalianVAT': [False, False, False, False, False, False, False, False],
#  'Document': [False, False, False, False, False, False, False, False],
#  'NumericId': [False, False, False, False, False, False, False, False],
#  'Municipality': [False, False, False, False, False, False, False, False],
#  'Name': [False, False, False, False, False, False, False, False],
#  'NaN': [False, False, False, False, False, False, False, False],
#  'PhoneNumber': [False, False, False, False, False, False, False, False],
#  'ProvinceCode': [False, False, False, False, False, False, False, False],
#  'Region': [False, False, False, False, False, False, False, False],
#  'String': [True, True, True, True, True, True, True, True],
#  'Surname': [False, False, False, False, False, False, False, False],
#  'Year': [False, False, False, False, False, False, False, False],
#  'BiologicalSex': [False, False, False, False, False, False, False, False],
#  'Boolean': [False, False, False, False, False, False, False, False],
#  'Plate': [False, False, False, False, False, False, False, False],
#  'CadastreCode': [False, False, False, False, False, False, False, False]}

# %%
df.values[:, 4]
# Out:
# array(['8', '3', '26', '18', '18', '40', '11', '62'], dtype=object)

# %%
predictor.predict_dataframe(df)
# Out:
#   column 0         CF-PERSONA Ragione Sociale Indirizzo casa     N.  \
# 0    Error  ItalianFiscalCode         Address        Address  Error
# 1    Error  ItalianFiscalCode         Address        Address  Error
# 2    Error  ItalianFiscalCode         Address        Address  Error
# 3    Error         ItalianVAT         Address        Address  Error
# 4    Error         ItalianVAT           Error        Address  Error
# 5    Error         ItalianVAT           Error        Address  Error
# 6    Error  ItalianFiscalCode         Address        Address  Error
# 7    Error  ItalianFiscalCode         Address        Address  Error
#
#               CAP Comune          PROV NUM. DOC. ANNO DOC IMPORTO DATA EMIS  \
# 0  ItalianZIPCode  Error         Error     Error    Error   Error      Date
# 1  ItalianZIPCode  Error  ProvinceCode     Error    Error   Error      Date
# 2  ItalianZIPCode  Error  ProvinceCode     Error    Error   Error      Date
# 3  ItalianZIPCode  Error  ProvinceCode     Error    Error   Error      Date
# 4  ItalianZIPCode  Error  ProvinceCode     Error    Error   Error      Date
# 5  ItalianZIPCode  Error  ProvinceCode     Error    Error   Error      Date
# 6  ItalianZIPCode  Error  ProvinceCode     Error    Error   Error      Date
# 7  ItalianZIPCode  Error  ProvinceCode     Error    Error   Error      Date
#
#   Nominativo
# 0        NaN
# 1        NaN
# 2      Error
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7      Error
